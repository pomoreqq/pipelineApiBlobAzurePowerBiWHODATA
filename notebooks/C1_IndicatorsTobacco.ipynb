# %%
import pandas as pd 
import requests
from jsonschema import validate
import json
import fastparquet

# %%
baseURL= 'https://ghoapi.azureedge.net/api/Indicator'

# %%
ListOfIndicatorCodesAndNamesTobacco = []

# %%
def getIndicator(baseurl,nameOfIndicator):
    response = requests.get(baseurl+f"?$filter=IndicatorName eq '{nameOfIndicator}'")
    data = response.json()
    return data

# %% [markdown]
# Tobacco control: Raise taxes on tobacco

# %% [markdown]
# 1.https://www.who.int/data/gho/data/indicators/indicator-details/GHO/affordability-of-the-most-sold-brand-of-cigarettes-(tobacco-control--raise-taxes)
# 2.https://www.who.int/data/gho/data/indicators/indicator-details/GHO/gho-tobacco-control-raise-taxes-national-taxes-pack-of-20

# %%
firstIndicator = getIndicator(baseURL,'Affordability - percentage of GDP per capita required to purchase 2000 cigarettes of the most sold brand')
ListOfIndicatorCodesAndNamesTobacco.append(firstIndicator['value'])
ListOfIndicatorCodesAndNamesTobacco
# Out:
# [[{'IndicatorCode': 'R_afford_gdp',
#    'IndicatorName': 'Affordability - percentage of GDP per capita required to purchase 2000 cigarettes of the most sold brand',
#    'Language': 'EN'}]]

# %%
secondIndicator = getIndicator(baseURL,'Retail price for tobacco and nicotine products')
ListOfIndicatorCodesAndNamesTobacco.append(secondIndicator['value'])
ListOfIndicatorCodesAndNamesTobacco
# Out:
# [[{'IndicatorCode': 'R_afford_gdp',
#    'IndicatorName': 'Affordability - percentage of GDP per capita required to purchase 2000 cigarettes of the most sold brand',
#    'Language': 'EN'}],
#  [{'IndicatorCode': 'TOB_R_PRICE',
#    'IndicatorName': 'Retail price for tobacco and nicotine products',
#    'Language': 'EN'}]]

# %% [markdown]
# Tobacco control: Enforce bans on tobacco advertising

# %% [markdown]
# 1. Tobacco ban on advertising on national television and radio
#
# 2. Tobacco advertising ban at point of sale
#
# 3. Tobacco ban on advertising: billboard and outdoor advertising
# 4. Ban on advertising on the internet

# %%
thirdIndicator = getIndicator(baseURL,'Ban on advertising: National TV and radio')
ListOfIndicatorCodesAndNamesTobacco.append(thirdIndicator['value'])
ListOfIndicatorCodesAndNamesTobacco
# Out:
# [[{'IndicatorCode': 'R_afford_gdp',
#    'IndicatorName': 'Affordability - percentage of GDP per capita required to purchase 2000 cigarettes of the most sold brand',
#    'Language': 'EN'}],
#  [{'IndicatorCode': 'TOB_R_PRICE',
#    'IndicatorName': 'Retail price for tobacco and nicotine products',
#    'Language': 'EN'}],
#  [{'IndicatorCode': 'E1_nat_tv_radio',
#    'IndicatorName': 'Ban on advertising: National TV and radio',
#    'Language': 'EN'}]]

# %%
fourthIndicator = getIndicator(baseURL,'Ban on advertising at point of sale')
ListOfIndicatorCodesAndNamesTobacco.append(fourthIndicator['value'])
ListOfIndicatorCodesAndNamesTobacco
# Out:
# [[{'IndicatorCode': 'R_afford_gdp',
#    'IndicatorName': 'Affordability - percentage of GDP per capita required to purchase 2000 cigarettes of the most sold brand',
#    'Language': 'EN'}],
#  [{'IndicatorCode': 'TOB_R_PRICE',
#    'IndicatorName': 'Retail price for tobacco and nicotine products',
#    'Language': 'EN'}],
#  [{'IndicatorCode': 'E1_nat_tv_radio',
#    'IndicatorName': 'Ban on advertising: National TV and radio',
#    'Language': 'EN'}],
#  [{'IndicatorCode': 'E6a_pt_of_sale',
#    'IndicatorName': 'Ban on advertising at point of sale',
#    'Language': 'EN'}]]

# %%
fifthIndicator = getIndicator(baseURL,'Ban on advertising: Billboards and outdoor advertising')
ListOfIndicatorCodesAndNamesTobacco.append(fifthIndicator['value'])
ListOfIndicatorCodesAndNamesTobacco
# Out:
# [[{'IndicatorCode': 'R_afford_gdp',
#    'IndicatorName': 'Affordability - percentage of GDP per capita required to purchase 2000 cigarettes of the most sold brand',
#    'Language': 'EN'}],
#  [{'IndicatorCode': 'TOB_R_PRICE',
#    'IndicatorName': 'Retail price for tobacco and nicotine products',
#    'Language': 'EN'}],
#  [{'IndicatorCode': 'E1_nat_tv_radio',
#    'IndicatorName': 'Ban on advertising: National TV and radio',
#    'Language': 'EN'}],
#  [{'IndicatorCode': 'E6a_pt_of_sale',
#    'IndicatorName': 'Ban on advertising at point of sale',
#    'Language': 'EN'}],
#  [{'IndicatorCode': 'E5_billboards',
#    'IndicatorName': 'Ban on advertising: Billboards and outdoor advertising',
#    'Language': 'EN'}]]

# %%
sixthIndicator = getIndicator(baseURL,'Ban on advertising: Internet')
ListOfIndicatorCodesAndNamesTobacco.append(sixthIndicator['value'])
ListOfIndicatorCodesAndNamesTobacco
# Out:
# [[{'IndicatorCode': 'R_afford_gdp',
#    'IndicatorName': 'Affordability - percentage of GDP per capita required to purchase 2000 cigarettes of the most sold brand',
#    'Language': 'EN'}],
#  [{'IndicatorCode': 'TOB_R_PRICE',
#    'IndicatorName': 'Retail price for tobacco and nicotine products',
#    'Language': 'EN'}],
#  [{'IndicatorCode': 'E1_nat_tv_radio',
#    'IndicatorName': 'Ban on advertising: National TV and radio',
#    'Language': 'EN'}],
#  [{'IndicatorCode': 'E6a_pt_of_sale',
#    'IndicatorName': 'Ban on advertising at point of sale',
#    'Language': 'EN'}],
#  [{'IndicatorCode': 'E5_billboards',
#    'IndicatorName': 'Ban on advertising: Billboards and outdoor advertising',
#    'Language': 'EN'}],
#  [{'IndicatorCode': 'E7_internet',
#    'IndicatorName': 'Ban on advertising: Internet',
#    'Language': 'EN'}]]

# %% [markdown]
# Tobacco control: Protect from tobacco smoke

# %% [markdown]
# 1. Tobacco smoke-free restaurants (national legislation)
# 2. Tobacco smoke-free public transport (national legislation)
# 3. Tobacco smoke-free indoor offices (national legislation)

# %%
seventhIndicator = getIndicator(baseURL,'National smoking ban in RESTAURANTS')
ListOfIndicatorCodesAndNamesTobacco.append(seventhIndicator['value'])
ListOfIndicatorCodesAndNamesTobacco
# Out:
# [[{'IndicatorCode': 'R_afford_gdp',
#    'IndicatorName': 'Affordability - percentage of GDP per capita required to purchase 2000 cigarettes of the most sold brand',
#    'Language': 'EN'}],
#  [{'IndicatorCode': 'TOB_R_PRICE',
#    'IndicatorName': 'Retail price for tobacco and nicotine products',
#    'Language': 'EN'}],
#  [{'IndicatorCode': 'E1_nat_tv_radio',
#    'IndicatorName': 'Ban on advertising: National TV and radio',
#    'Language': 'EN'}],
#  [{'IndicatorCode': 'E6a_pt_of_sale',
#    'IndicatorName': 'Ban on advertising at point of sale',
#    'Language': 'EN'}],
#  [{'IndicatorCode': 'E5_billboards',
#    'IndicatorName': 'Ban on advertising: Billboards and outdoor advertising',
#    'Language': 'EN'}],
#  [{'IndicatorCode': 'E7_internet',
#    'IndicatorName': 'Ban on advertising: Internet',
#    'Language': 'EN'}],
#  [{'IndicatorCode': 'P6_restaurants',
#    'IndicatorName': 'National smoking ban in RESTAURANTS',
#    'Language': 'EN'}]]

# %%
eigthIndicator = getIndicator(baseURL,'National smoking ban in PUBLIC TRANSPORT')
ListOfIndicatorCodesAndNamesTobacco.append(eightIndicator['value'])
ListOfIndicatorCodesAndNamesTobacco
# Out:
# [[{'IndicatorCode': 'R_afford_gdp',
#    'IndicatorName': 'Affordability - percentage of GDP per capita required to purchase 2000 cigarettes of the most sold brand',
#    'Language': 'EN'}],
#  [{'IndicatorCode': 'TOB_R_PRICE',
#    'IndicatorName': 'Retail price for tobacco and nicotine products',
#    'Language': 'EN'}],
#  [{'IndicatorCode': 'E1_nat_tv_radio',
#    'IndicatorName': 'Ban on advertising: National TV and radio',
#    'Language': 'EN'}],
#  [{'IndicatorCode': 'E6a_pt_of_sale',
#    'IndicatorName': 'Ban on advertising at point of sale',
#    'Language': 'EN'}],
#  [{'IndicatorCode': 'E5_billboards',
#    'IndicatorName': 'Ban on advertising: Billboards and outdoor advertising',
#    'Language': 'EN'}],
#  [{'IndicatorCode': 'E7_internet',
#    'IndicatorName': 'Ban on advertising: Internet',
#    'Language': 'EN'}],
#  [{'IndicatorCode': 'P6_restaurants',
#    'IndicatorName': 'National smoking ban in RESTAURANTS',
#    'Language': 'EN'}],
# ...

# %%
ninthIndicator = getIndicator(baseURL,'National smoking ban in INDOOR OFFICES')
ListOfIndicatorCodesAndNamesTobacco.append(ninthIndicator['value'])
ListOfIndicatorCodesAndNamesTobacco
# Out:
# [[{'IndicatorCode': 'R_afford_gdp',
#    'IndicatorName': 'Affordability - percentage of GDP per capita required to purchase 2000 cigarettes of the most sold brand',
#    'Language': 'EN'}],
#  [{'IndicatorCode': 'TOB_R_PRICE',
#    'IndicatorName': 'Retail price for tobacco and nicotine products',
#    'Language': 'EN'}],
#  [{'IndicatorCode': 'E1_nat_tv_radio',
#    'IndicatorName': 'Ban on advertising: National TV and radio',
#    'Language': 'EN'}],
#  [{'IndicatorCode': 'E6a_pt_of_sale',
#    'IndicatorName': 'Ban on advertising at point of sale',
#    'Language': 'EN'}],
#  [{'IndicatorCode': 'E5_billboards',
#    'IndicatorName': 'Ban on advertising: Billboards and outdoor advertising',
#    'Language': 'EN'}],
#  [{'IndicatorCode': 'E7_internet',
#    'IndicatorName': 'Ban on advertising: Internet',
#    'Language': 'EN'}],
#  [{'IndicatorCode': 'P6_restaurants',
#    'IndicatorName': 'National smoking ban in RESTAURANTS',
#    'Language': 'EN'}],
# ...

# %%
flattenListOfIndicators = [x for item in ListOfIndicatorCodesAndNamesTobacco for x in item]
dfListOfIndicators = pd.DataFrame(flattenListOfIndicators)
dfListOfIndicators
# Out:
#      IndicatorCode                                      IndicatorName Language
# 0     R_afford_gdp  Affordability - percentage of GDP per capita r...       EN
# 1      TOB_R_PRICE     Retail price for tobacco and nicotine products       EN
# 2  E1_nat_tv_radio          Ban on advertising: National TV and radio       EN
# 3   E6a_pt_of_sale                Ban on advertising at point of sale       EN
# 4    E5_billboards  Ban on advertising: Billboards and outdoor adv...       EN
# 5      E7_internet                       Ban on advertising: Internet       EN
# 6   P6_restaurants                National smoking ban in RESTAURANTS       EN
# 7    P8_pub_transp           National smoking ban in PUBLIC TRANSPORT       EN
# 8    P5_indoor_off             National smoking ban in INDOOR OFFICES       EN

# %%
categories = [
    'Tobacco control: Raise taxes on tobacco',     # 0
    'Tobacco control: Raise taxes on tobacco',     # 1
    'Tobacco control: Enforce bans on tobacco advertising',  # 2
    'Tobacco control: Enforce bans on tobacco advertising',  # 3
    'Tobacco control: Enforce bans on tobacco advertising',  # 4
    'Tobacco control: Enforce bans on tobacco advertising', # 5
    'Tobacco control: Protect from tobacco smoke', # 6
    'Tobacco control: Protect from tobacco smoke', # 7
    'Tobacco control: Protect from tobacco smoke'  # 8
]

# %%
dfListOfIndicators["Category"] = categories
dfListOfIndicators
# Out:
#      IndicatorCode                                      IndicatorName  \
# 0     R_afford_gdp  Affordability - percentage of GDP per capita r...
# 1      TOB_R_PRICE     Retail price for tobacco and nicotine products
# 2  E1_nat_tv_radio          Ban on advertising: National TV and radio
# 3   E6a_pt_of_sale                Ban on advertising at point of sale
# 4    E5_billboards  Ban on advertising: Billboards and outdoor adv...
# 5      E7_internet                       Ban on advertising: Internet
# 6   P6_restaurants                National smoking ban in RESTAURANTS
# 7    P8_pub_transp           National smoking ban in PUBLIC TRANSPORT
# 8    P5_indoor_off             National smoking ban in INDOOR OFFICES
#
#   Language                                           Category
# 0       EN            Tobacco control: Raise taxes on tobacco
# 1       EN            Tobacco control: Raise taxes on tobacco
# 2       EN  Tobacco control: Enforce bans on tobacco adver...
# ...

# %%
dfListOfIndicators.to_parquet(path='../dataRawBeforeBlob/indicators/tobaccoIndicators.parquet',engine='fastparquet',index=None,)
